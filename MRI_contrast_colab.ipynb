# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanArvidsson/EEN200/blob/main/MRI_contrast_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Först behövde jag köra raden nedan /Jonathan
#!pip install ipympl
#%matplotlib widget
import MRI_contrast as Mc
from importlib import reload
reload(Mc)

gui1 = Mc.MRI_contrast_gui('spin echo')
# Out:
# VBox(children=(FloatSlider(value=0.5, description='TR (s):', layout=Layout(width='70%'), max=10.0), FloatSlide…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
gui2 = Mc.MRI_contrast_gui('inversion recovery')
# Out:
# VBox(children=(FloatSlider(value=0.5, description='T1:', layout=Layout(width='70%'), max=10.0), FloatSlider(va…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
gui3 = Mc.MRI_contrast_gui('gradient echo')
# Out:
# VBox(children=(FloatSlider(value=0.5, description='T1:', layout=Layout(width='70%'), max=10.0), FloatSlider(va…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
